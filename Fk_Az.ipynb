# %%
#importing necessary analysis libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Loading dataframe of flipkart
az = pd.read_csv(r'C:\Users\poulo\az.csv')
az.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
#Loading dataframe of flipkart
fk = pd.read_csv(r'C:\Users\poulo\fk.csv')
fk.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
fk_short=fk[['uniq_id','product_name','retail_price','discounted_price']]
az_short=az[['uniq_id','product_name','retail_price','discounted_price']]

# %%
fk_short.head()
# Out:
#                             uniq_id                           product_name  \
# 0  c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 1  7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# 2  f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 3  0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#    retail_price  discounted_price
# 0         999.0             379.0
# 1       32157.0           22646.0
# 2         999.0             499.0
# 3         699.0             267.0
# 4         220.0             210.0

# %%
az_short.head()
# Out:
#                             uniq_id                           product_name  \
# 0  c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 1  7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# 2  f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 3  0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#    retail_price  discounted_price
# 0           982               438
# 1         32143             29121
# 2           991               551
# 3           694               325
# 4           208               258

# %%
Merged=pd.merge(fk_short,az_short, on="uniq_id", how='left')

# %%
Merged.head()
# Out:
#                             uniq_id                         product_name_x  \
# 0  c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 1  7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# 2  f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 3  0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#    retail_price_x  discounted_price_x                         product_name_y  \
# 0           999.0               379.0    Alisha Solid Women's Cycling Shorts
# 1         32157.0             22646.0    FabHomeDecor Fabric Double Sofa Bed
# 2           999.0               499.0                             AW Bellies
# 3           699.0               267.0    Alisha Solid Women's Cycling Shorts
# 4           220.0               210.0  Sicons All Purpose Arnica Dog Shampoo
#
#    retail_price_y  discounted_price_y
# ...

# %%
Merged_Final=Merged.drop(['uniq_id'],axis=1)

# %%
Merged_Final.head()
# Out:
#                           product_name_x  retail_price_x  discounted_price_x  \
# 0    Alisha Solid Women's Cycling Shorts           999.0               379.0
# 1    FabHomeDecor Fabric Double Sofa Bed         32157.0             22646.0
# 2                             AW Bellies           999.0               499.0
# 3    Alisha Solid Women's Cycling Shorts           699.0               267.0
# 4  Sicons All Purpose Arnica Dog Shampoo           220.0               210.0
#
#                           product_name_y  retail_price_y  discounted_price_y
# 0    Alisha Solid Women's Cycling Shorts             982                 438
# 1    FabHomeDecor Fabric Double Sofa Bed           32143               29121
# 2                             AW Bellies             991                 551
# 3    Alisha Solid Women's Cycling Shorts             694                 325
# 4  Sicons All Purpose Arnica Dog Shampoo             208                 258

# %%
Merged_Final = Merged_Final.rename(columns={
    'product_name_x': 'Product name in Flipkart',
    'retail_price_x': 'Retail Price in Flipkart',
    'discounted_price_x': 'Discounted Price in Flipkart',
    'product_name_y': 'Product name in Amazon', 
    'retail_price_y': 'Retail Price in Amazon',
    'discounted_price_y': 'Discounted Price in Amazon'})

# %%
Merged_Final.head()
# Out:
#                 Product name in Flipkart  Retail Price in Flipkart  \
# 0    Alisha Solid Women's Cycling Shorts                     999.0
# 1    FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                             AW Bellies                     999.0
# 3    Alisha Solid Women's Cycling Shorts                     699.0
# 4  Sicons All Purpose Arnica Dog Shampoo                     220.0
#
#    Discounted Price in Flipkart                 Product name in Amazon  \
# 0                         379.0    Alisha Solid Women's Cycling Shorts
# 1                       22646.0    FabHomeDecor Fabric Double Sofa Bed
# 2                         499.0                             AW Bellies
# 3                         267.0    Alisha Solid Women's Cycling Shorts
# 4                         210.0  Sicons All Purpose Arnica Dog Shampoo
#
#    Retail Price in Amazon  Discounted Price in Amazon
# 0                     982                         438
# ...

# %%
Merged_Final['Product name']=Merged_Final['Product name in Flipkart']

# %%
first_column = Merged_Final.pop('Product name')
Merged_Final.insert(0,'Product name', first_column)
Merged_Final.head()
# Out:
#                             Product name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                 Product name in Flipkart  Retail Price in Flipkart  \
# 0    Alisha Solid Women's Cycling Shorts                     999.0
# 1    FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                             AW Bellies                     999.0
# 3    Alisha Solid Women's Cycling Shorts                     699.0
# 4  Sicons All Purpose Arnica Dog Shampoo                     220.0
#
#    Discounted Price in Flipkart                 Product name in Amazon  \
# 0                         379.0    Alisha Solid Women's Cycling Shorts
# 1                       22646.0    FabHomeDecor Fabric Double Sofa Bed
# 2                         499.0                             AW Bellies
# ...

# %%
Merged_Final['Product name']
# Out:
# 0            Alisha Solid Women's Cycling Shorts
# 1            FabHomeDecor Fabric Double Sofa Bed
# 2                                     AW Bellies
# 3            Alisha Solid Women's Cycling Shorts
# 4          Sicons All Purpose Arnica Dog Shampoo
#                           ...
# 19995             WallDesign Small Vinyl Sticker
# 19996    Wallmantra Large Vinyl Stickers Sticker
# 19997    Elite Collection Medium Acrylic Sticker
# 19998    Elite Collection Medium Acrylic Sticker
# 19999    Elite Collection Medium Acrylic Sticker
# Name: Product name, Length: 20000, dtype: object

# %%
#Change input in isin(["*********HERE*********"])
Search_Result = Merged_Final["Product name"].isin(["Alisha Solid Women's Cycling Shorts"])     #<-------------------- HERE INPUT
print('No of search inputs matching:',Search_Result.sum())
print('The matched results are:')
Merged_Final[Search_Result]
# Out:
# No of search inputs matching: 7
# The matched results are:
#                            Product name             Product name in Flipkart  \
# 0   Alisha Solid Women's Cycling Shorts  Alisha Solid Women's Cycling Shorts
# 3   Alisha Solid Women's Cycling Shorts  Alisha Solid Women's Cycling Shorts
# 6   Alisha Solid Women's Cycling Shorts  Alisha Solid Women's Cycling Shorts
# 9   Alisha Solid Women's Cycling Shorts  Alisha Solid Women's Cycling Shorts
# 13  Alisha Solid Women's Cycling Shorts  Alisha Solid Women's Cycling Shorts
# 15  Alisha Solid Women's Cycling Shorts  Alisha Solid Women's Cycling Shorts
# 21  Alisha Solid Women's Cycling Shorts  Alisha Solid Women's Cycling Shorts
#
#     Retail Price in Flipkart  Discounted Price in Flipkart  \
# 0                      999.0                         379.0
# 3                      699.0                         267.0
# 6                     1199.0                         479.0
# ...
